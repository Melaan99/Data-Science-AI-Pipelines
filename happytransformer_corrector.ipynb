# %% [markdown]
# <a href="https://colab.research.google.com/github/Melaan99/Data-Science-AI-Pipelines/blob/main/happytransformer_corrector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install happytransformer

# %%
from happytransformer import HappyTextToText
text = HappyTextToText("T5", "prithivida/grammar_error_correcter_v1")

# %%
from happytransformer import TTSettings
top_k_sampling_settings = TTSettings(do_sample=True, top_k=50, temperature=0.7, min_length=1, max_length=50)

# %%
result = text.generate_text("I likes to eatt. applees", args=top_k_sampling_settings)
print(result.text)
# Out:
# Device set to use cpu
# I like to eat apples.

# %%
result_2 = text.generate_text("After we played ches, I read my fav bok and wen to bed. ", args=top_k_sampling_settings)
print(result_2.text)
# Out:
# After we played chess, I read my fav book and went to bed.

# %%
gramformer_settings = TTSettings(do_sample=True, top_k=20, temperature=0.7, min_length=1, max_length=100, early_stopping=True)

# %%
result_3 = text.generate_text("I wentt too the stores to buys food.", args=top_k_sampling_settings)
print(result_3.text)
# Out:
# I went to the stores to buy food.
